# %% [markdown]
# **Importing the required libraries**

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd
import re
import time
from IPython.core.display import HTML
import webbrowser

# %% [markdown]
# **Scraping Dermnet website**

# %%
# Creating an instance of the Chrome web browser
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# URL to the dermnet website
url = "https://dermnetnz.org/image-library"

# Navigating to the specified url in chrome
driver.get(url)
# maximizing the browser window so that it takes up the entire screen
driver.maximize_window()

# %%
# Finding all the skin_disorders listed on the main page
skin_disorder_tag_main_page = driver.find_elements("xpath", '//a[@class="imageList__group__item"]')

# For loop to extract the skin disorder names and the link to the skin_disorders 
disorder_names = [] 
link_list= []
for tag in skin_disorder_tag_main_page:
    disorder_names.append(tag.text)
    link_list.append(tag.get_attribute("href"))

# Previewing the lists created:
print(f'The first 10 skin condition names: \n {disorder_names[:10]}\n')
print(f'The first 10 links to skin condition image links:\n{link_list[:10]}')
# Out:
# The first 10 skin condition names:
#  ['Acne affecting the back images', 'Acne affecting the face images', 'Acne and other follicular disorder images', 'Acquired dermal macular hyperpigmentation images', 'Acral lentiginous melanoma images', 'Actinic keratosis affecting the face images', 'Actinic keratosis affecting the hand images', 'Actinic keratosis affecting the legs and feet images', 'Actinic keratosis affecting the scalp images', 'Actinic keratosis dermoscopy images']
#
# The first 10 links to skin condition image links:
# ['https://dermnetnz.org/topics/acne-affecting-the-back-images/?stage=Live', 'https://dermnetnz.org/topics/acne-face-images/?stage=Live', 'https://dermnetnz.org/image-catalogue/acne-and-other-follicular-disorder-images/?stage=Live', 'https://dermnetnz.org/topics/acquired-dermal-macular-hyperpigmentation-images/?stage=Live', 'https://dermnetnz.org/topics/acral-lentiginous-melanoma-images/?stage=Live', 'https://dermnetnz.org/topics/actinic-keratosis-face-images/?stage=Live', 'https://dermnetnz.org/topics/actinic-keratosis-affecting-the-hand-images/?stage=Live', 'https://dermnetnz.org/topics/actinic-keratosis-leg-and-foot-images/?stage=Live', 'https://dermnetnz.org/topics/actinic-keratosis-scalp-images/?stage=Live', 'https://dermnetnz.org/topics/actinic-keratosis-dermoscopy-images/?stage=Live']

# %%
# The number of skin_disorders listed in the website
print(f'The are {len(disorder_names)} skin conditions listed in the DermNet website.')
# Out:
# The are 294 skin conditions listed in the DermNet website.

# %%
# Creating a dataframe with two columns, the skin_disorder names and the links to the images of the skin disorders
name_link_df = pd.DataFrame({'skin_disorder_name': disorder_names, 'link': link_list})

# Saving the dataframe as a csv file
name_link_df.to_csv('Data/name_link.csv', index=False)

# Previewing the first five rows of the dataframe
name_link_df.head()
# Out:
#                                  skin_disorder_name  \
# 0                    Acne affecting the back images
# 1                    Acne affecting the face images
# 2         Acne and other follicular disorder images
# 3  Acquired dermal macular hyperpigmentation images
# 4                 Acral lentiginous melanoma images
#
#                                                 link
# 0  https://dermnetnz.org/topics/acne-affecting-th...
# 1  https://dermnetnz.org/topics/acne-face-images/...
# 2  https://dermnetnz.org/image-catalogue/acne-and...
# 3  https://dermnetnz.org/topics/acquired-dermal-m...
# 4  https://dermnetnz.org/topics/acral-lentiginous...

# %%
# initialize the webdriver
# Note ⏰ This cell takes about 1/2 an hour to complete running.

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# create an empty list to store the dataframes for each link/disease pair
dfs = []
# loop through each link/disease pair
for link, disease_name in zip(link_list, disorder_names):
    # create an empty list to store the image URLs
    image_disease = []

    try:
        # navigate to the link
        driver.get(link)

        # maximize the window to ensure all elements are visible
        driver.maximize_window()

        # find all the elements on the page with the class "imageLinkBlock__item__image"
        skin_image_disorder = driver.find_elements("xpath", '//div[@class="imageLinkBlock__item__image"]')

        # loop through each element and find all the images within it
        for image in skin_image_disorder:
            list_ = image.find_elements("tag name", "img")
            for lists in list_:
                # add each image URL to the image_disease list
                image_disease.append(lists.get_attribute("src"))

        # create a list of dictionaries, where each dictionary represents a row in the DataFrame
        # each dictionary contains an image URL and the disease name
        rows = [{'skin_disorder_name': disease_name, 'images': url} for url in image_disease]

        # create the DataFrame using the list of dictionaries
        df = pd.DataFrame(rows, columns=['skin_disorder_name', 'images'])

        # add the dataframe to the list of dataframes
        dfs.append(df)

    except Exception as e:
        # if an error occurs, print the error message and move to the next link/disease pair
        print(f"Error occurred for {disease_name}: {str(e)}")
        continue

# concatenate all the dataframes into a single dataframe
result_df = pd.concat(dfs)

# Turning all the skin_disorder_names to lower case:
result_df['skin_disorder_name'] = result_df['skin_disorder_name'].map(lambda x: x.lower())

# save the result dataframe to a CSV file named "data.csv"
result_df.to_csv('Data/data1-294.csv', index=False)

# %%
# DataFrame with all the 294 images:
image_df = pd.read_csv('Data/data1-294.csv')

# Previewing the first 3 rows of the dataframe
image_df.head(3)
# Out:
#                skin_disorder_name  \
# 0  acne affecting the back images
# 1  acne affecting the back images
# 2  acne affecting the back images
#
#                                               images
# 0  https://dermnetnz.org/assets/Uploads/acne/acne...
# 1  https://dermnetnz.org/assets/Uploads/acne/acne...
# 2  https://dermnetnz.org/assets/Uploads/acne/acne...

# %%
# Function takes in the image url and returns an html <img> tag that displays the image
def to_img_tag(path):
    return '<img src="'+ path + '" width="50" >'

# %%
# Save the HTML table to a file
with open('Data/image_table.html', 'w') as f:
    f.write(image_df.to_html(escape=False,formatters=dict(images=to_img_tag)))

# %%
# Open the HTML file in the default web browser
webbrowser.open('Data/image_table.html')
# Out:
# True

# %%
# Downloading and Saving the images into a folder:
# Note ⏰ This cell takes about 1 and 1/2 hours to complete running.

import requests as rq
import os
import pathlib
import pandas as pd


def save_image(folder: str, name: str, url: str, index:int):
    # Get the data from the url
    image_source = rq.get(url)

    # If there's a suffix, we will grab that
    suffix = pathlib.Path(url).suffix

    # Check if the suffix is one of the following
    if suffix not in ['.jpg', '.jpeg', '.png', '.gif']:
        # Default to .png
        output = name + str(index) + '.png'

    else:
        output = name + str(index) + suffix

    # Check first if folder exists, else create a new one
    if not os.path.exists(folder):
        os.makedirs(folder)

    # Create our output in the specified folder (wb = write bytes)
    with open(f'{folder}{output}', 'wb') as file:
        file.write(image_source.content)
        print(f'Successfully downloaded: {output}')


if __name__ == '__main__':
    # Load the dataframe with image urls and disease names
    df = pd.read_csv('Data/data1-294.csv')

    # Loop through the dataframe
    for index, row in df.iterrows():
        # Get the image url and disease name
        image_url = row['images']
        disease_name = row['skin_disorder_name']

        # Save the image
        save_image('Images/', disease_name, image_url, index)
# Out:
# Successfully downloaded: acne affecting the back images0.jpg
# Successfully downloaded: acne affecting the back images1.jpg
# Successfully downloaded: acne affecting the back images2.jpg
# Successfully downloaded: acne affecting the back images3.jpg
# Successfully downloaded: acne affecting the back images4.jpg
# Successfully downloaded: acne affecting the back images5.jpg
# Successfully downloaded: acne affecting the back images6.jpg
# Successfully downloaded: acne affecting the back images7.jpg
# Successfully downloaded: acne affecting the back images8.jpg
# Successfully downloaded: acne affecting the back images9.jpg
# Successfully downloaded: acne affecting the back images10.jpg
# Successfully downloaded: acne affecting the back images11.jpg
# Successfully downloaded: acne affecting the back images12.jpg
# Successfully downloaded: acne affecting the back images13.jpg
# Successfully downloaded: acne affecting the back images14.jpg
# Successfully downloaded: acne affecting the back images15.jpg
# Successfully downloaded: acne affecting the back images16.jpg
# Successfully downloaded: acne affecting the back images17.jpg
# Successfully downloaded: acne affecting the back images18.jpg
# Successfully downloaded: acne affecting the back images19.jpg
# Successfully downloaded: acne affecting the back images20.jpg
# Successfully downloaded: acne affecting the back images21.jpg
# Successfully downloaded: acne affecting the back images22.jpg
# Successfully downloaded: acne affecting the back images23.jpg
# Successfully downloaded: acne affecting the back images24.jpg
# Successfully downloaded: acne affecting the back images25.jpg
# Successfully downloaded: acne affecting the back images26.jpg
# Successfully downloaded: acne affecting the back images27.jpg
# Successfully downloaded: acne affecting the back images28.jpg
# Successfully downloaded: acne affecting the back images29.jpg
# Successfully downloaded: acne affecting the back images30.jpg
# Successfully downloaded: acne affecting the back images31.jpg
# Successfully downloaded: acne affecting the back images32.jpg
# Successfully downloaded: acne affecting the back images33.jpg
# Successfully downloaded: acne affecting the back images34.jpg
# Successfully downloaded: acne affecting the back images35.jpg
# Successfully downloaded: acne affecting the back images36.jpg
# Successfully downloaded: acne affecting the back images37.jpg
# Successfully downloaded: acne affecting the back images38.jpg
# Successfully downloaded: acne affecting the back images39.jpg
# Successfully downloaded: acne affecting the back images40.jpg
# Successfully downloaded: acne affecting the face images41.jpg
# Successfully downloaded: acne affecting the face images42.png
# Successfully downloaded: acne affecting the face images43.png
# Successfully downloaded: acne affecting the face images44.png
# Successfully downloaded: acne affecting the face images45.png
# Successfully downloaded: acne affecting the face images46.png
# Successfully downloaded: acne affecting the face images47.png
# Successfully downloaded: acne affecting the face images48.png
# Successfully downloaded: acne affecting the face images49.png
# Successfully downloaded: acne affecting the face images50.jpg
# Successfully downloaded: acne affecting the face images51.jpg
# Successfully downloaded: acne affecting the face images52.jpg
# Successfully downloaded: acne affecting the face images53.jpg
# Successfully downloaded: acne affecting the face images54.jpg
# Successfully downloaded: acne affecting the face images55.jpg
# Successfully downloaded: acne affecting the face images56.jpg
# Successfully downloaded: acne affecting the face images57.jpg
# Successfully downloaded: acne affecting the face images58.jpg
# Successfully downloaded: acne affecting the face images59.jpg
# Successfully downloaded: acne affecting the face images60.jpg
# Successfully downloaded: acne affecting the face images61.jpg
# Successfully downloaded: acne affecting the face images62.jpg
# Successfully downloaded: acne affecting the face images63.jpg
# Successfully downloaded: acne affecting the face images64.jpg
# Successfully downloaded: acne affecting the face images65.jpg
# Successfully downloaded: acne affecting the face images66.jpg
# Successfully downloaded: acne affecting the face images67.jpg
# Successfully downloaded: acne affecting the face images68.jpg
# Successfully downloaded: acne affecting the face images69.jpg
# Successfully downloaded: acne affecting the face images70.jpg
# Successfully downloaded: acne affecting the face images71.jpg
# Successfully downloaded: acne affecting the face images72.jpg
# Successfully downloaded: acne affecting the face images73.jpg
# Successfully downloaded: acne affecting the face images74.jpg
# Successfully downloaded: acne affecting the face images75.jpg
# Successfully downloaded: acne affecting the face images76.jpg
# Successfully downloaded: acne affecting the face images77.jpg
# Successfully downloaded: acne affecting the face images78.jpg
# Successfully downloaded: acne affecting the face images79.jpg
# Successfully downloaded: acne affecting the face images80.jpg
# Successfully downloaded: acne affecting the face images81.jpg
# Successfully downloaded: acne affecting the face images82.jpg
# Successfully downloaded: acne affecting the face images83.jpg
# Successfully downloaded: acne affecting the face images84.jpg
# Successfully downloaded: acne affecting the face images85.jpg
# Successfully downloaded: acne affecting the face images86.jpg
# Successfully downloaded: acne affecting the face images87.jpg
# Successfully downloaded: acne affecting the face images88.jpg
# Successfully downloaded: acne affecting the face images89.jpg
# Successfully downloaded: acne affecting the face images90.jpg
# Successfully downloaded: acne affecting the face images91.jpg
# Successfully downloaded: acne affecting the face images92.jpg
# Successfully downloaded: acne affecting the face images93.jpg
# Successfully downloaded: acne affecting the face images94.jpg
# Successfully downloaded: acne affecting the face images95.jpg
# Successfully downloaded: acne affecting the face images96.jpg
# Successfully downloaded: acne affecting the face images97.jpg
# Successfully downloaded: acne affecting the face images98.jpg
# Successfully downloaded: acne affecting the face images99.jpg
# Successfully downloaded: acne affecting the face images100.jpg
# Successfully downloaded: acne affecting the face images101.jpg
# Successfully downloaded: acne affecting the face images102.jpg
# Successfully downloaded: acne affecting the face images103.jpg
# Successfully downloaded: acne affecting the face images104.jpg
# Successfully downloaded: acne affecting the face images105.jpg
# Successfully downloaded: acne affecting the face images106.jpg
# Successfully downloaded: acne affecting the face images107.jpg
# Successfully downloaded: acne affecting the face images108.jpg
# Successfully downloaded: acne affecting the face images109.jpg
# Successfully downloaded: acne affecting the face images110.jpg
# Successfully downloaded: acne affecting the face images111.jpg
# Successfully downloaded: acne affecting the face images112.jpg
# Successfully downloaded: acne affecting the face images113.jpg
# Successfully downloaded: acne affecting the face images114.jpg
# Successfully downloaded: acne affecting the face images115.jpg
# Successfully downloaded: acne affecting the face images116.jpg
# Successfully downloaded: acne affecting the face images117.jpg
# Successfully downloaded: acne affecting the face images118.jpg
# Successfully downloaded: acne affecting the face images119.jpg
# Successfully downloaded: acne affecting the face images120.jpg
# Successfully downloaded: acne affecting the face images121.jpg
# Successfully downloaded: acne affecting the face images122.jpg
# Successfully downloaded: acne affecting the face images123.jpg
# Successfully downloaded: acne affecting the face images124.jpg
# Successfully downloaded: acne affecting the face images125.jpg
# Successfully downloaded: acne affecting the face images126.jpg
# Successfully downloaded: acne affecting the face images127.jpg
# Successfully downloaded: acne affecting the face images128.jpg
# Successfully downloaded: acne affecting the face images129.jpg
# Successfully downloaded: acne affecting the face images130.jpg
# Successfully downloaded: acne affecting the face images131.jpg
# Successfully downloaded: acne affecting the face images132.jpg
# Successfully downloaded: acne affecting the face images133.jpg
# Successfully downloaded: acne affecting the face images134.jpg
# Successfully downloaded: acne affecting the face images135.jpg
# Successfully downloaded: acne affecting the face images136.jpg
# Successfully downloaded: acne affecting the face images137.jpg
# Successfully downloaded: acne affecting the face images138.jpg
# Successfully downloaded: acne affecting the face images139.jpg
# Successfully downloaded: acne affecting the face images140.jpg
# Successfully downloaded: acne affecting the face images141.jpg
# Successfully downloaded: acne affecting the face images142.jpg
# Successfully downloaded: acne affecting the face images143.jpg
# Successfully downloaded: acne affecting the face images144.jpg
# Successfully downloaded: acne affecting the face images145.jpg
# Successfully downloaded: acne affecting the face images146.jpg
# Successfully downloaded: acne affecting the face images147.jpg
# Successfully downloaded: acne affecting the face images148.jpg
# Successfully downloaded: acne affecting the face images149.jpg
# Successfully downloaded: acne affecting the face images150.jpg
# Successfully downloaded: acne affecting the face images151.jpg
# Successfully downloaded: acne affecting the face images152.jpg
# Successfully downloaded: acne affecting the face images153.jpg
# Successfully downloaded: acne affecting the face images154.jpg
# Successfully downloaded: acne affecting the face images155.jpg
# Successfully downloaded: acne affecting the face images156.jpg
# Successfully downloaded: acne affecting the face images157.jpg
# Successfully downloaded: acne affecting the face images158.jpg
# Successfully downloaded: acne affecting the face images159.jpg
# Successfully downloaded: acne affecting the face images160.jpg
# Successfully downloaded: acne affecting the face images161.jpg
# Successfully downloaded: acne affecting the face images162.jpg
# Successfully downloaded: acne affecting the face images163.jpg
# Successfully downloaded: acne affecting the face images164.jpg
# Successfully downloaded: acne affecting the face images165.jpg
# Successfully downloaded: acne affecting the face images166.jpg
# Successfully downloaded: acne affecting the face images167.jpg
# Successfully downloaded: acne affecting the face images168.jpg
# Successfully downloaded: acne affecting the face images169.jpg
# Successfully downloaded: acne affecting the face images170.jpg
# Successfully downloaded: acne affecting the face images171.jpg
# Successfully downloaded: acne affecting the face images172.jpg
# Successfully downloaded: acne affecting the face images173.jpg
# Successfully downloaded: acne affecting the face images174.jpg
# Successfully downloaded: acne affecting the face images175.jpg
# Successfully downloaded: acne affecting the face images176.jpg
# Successfully downloaded: acne affecting the face images177.jpg
# Successfully downloaded: acne affecting the face images178.jpg
# Successfully downloaded: acne affecting the face images179.jpg
# Successfully downloaded: acne affecting the face images180.jpg
# Successfully downloaded: acne affecting the face images181.jpg
# Successfully downloaded: acne affecting the face images182.jpg
# Successfully downloaded: acne affecting the face images183.jpg
# Successfully downloaded: acne affecting the face images184.jpg
# Successfully downloaded: acne affecting the face images185.jpg
# Successfully downloaded: acne affecting the face images186.jpg
# Successfully downloaded: acne affecting the face images187.jpg
# Successfully downloaded: acne affecting the face images188.jpg
# Successfully downloaded: acne affecting the face images189.jpg
# Successfully downloaded: acne affecting the face images190.jpg
# Successfully downloaded: acne affecting the face images191.jpg
# Successfully downloaded: acne affecting the face images192.jpg
# Successfully downloaded: acne affecting the face images193.jpg
# Successfully downloaded: acne affecting the face images194.jpg
# Successfully downloaded: acne affecting the face images195.jpg
# Successfully downloaded: acne affecting the face images196.jpg
# Successfully downloaded: acne affecting the face images197.jpg
# Successfully downloaded: acne affecting the face images198.jpg
# Successfully downloaded: acne affecting the face images199.jpg
# Successfully downloaded: acne affecting the face images200.jpg
# Successfully downloaded: acne affecting the face images201.jpg
# Successfully downloaded: acne affecting the face images202.jpg
# Successfully downloaded: acne affecting the face images203.jpg
# Successfully downloaded: acne affecting the face images204.jpg
# Successfully downloaded: acne affecting the face images205.jpg
# Successfully downloaded: acne affecting the face images206.jpg
# Successfully downloaded: acne affecting the face images207.jpg
# Successfully downloaded: acne affecting the face images208.jpg
# Successfully downloaded: acne affecting the face images209.jpg
# Successfully downloaded: acne affecting the face images210.jpg
# Successfully downloaded: acne affecting the face images211.jpg
# Successfully downloaded: acne affecting the face images212.jpg
# Successfully downloaded: acne affecting the face images213.jpg
# Successfully downloaded: acne affecting the face images214.jpg
# Successfully downloaded: acne affecting the face images215.jpg
# Successfully downloaded: acne affecting the face images216.jpg
# Successfully downloaded: acne affecting the face images217.jpg
# Successfully downloaded: acne affecting the face images218.jpg
# Successfully downloaded: acne affecting the face images219.jpg
# Successfully downloaded: acne affecting the face images220.jpg
# Successfully downloaded: acne affecting the face images221.jpg
# Successfully downloaded: acne affecting the face images222.jpg
# Successfully downloaded: acne affecting the face images223.jpg
# Successfully downloaded: acne affecting the face images224.jpg
# Successfully downloaded: acne affecting the face images225.jpg
# Successfully downloaded: acne affecting the face images226.jpg
# Successfully downloaded: acne affecting the face images227.jpg
# Successfully downloaded: acne affecting the face images228.jpg
# Successfully downloaded: acne affecting the face images229.jpg
# Successfully downloaded: acne affecting the face images230.jpg
# Successfully downloaded: acne affecting the face images231.jpg
# Successfully downloaded: acne affecting the face images232.jpg
# Successfully downloaded: acne affecting the face images233.jpg
# Successfully downloaded: acne affecting the face images234.jpg
# Successfully downloaded: acne affecting the face images235.jpg
# Successfully downloaded: acne affecting the face images236.jpg
# Successfully downloaded: acne affecting the face images237.jpg
# Successfully downloaded: acne affecting the face images238.png
# Successfully downloaded: acne affecting the face images239.jpg
# Successfully downloaded: acne affecting the face images240.jpg
# Successfully downloaded: acne affecting the face images241.jpg
# Successfully downloaded: acne affecting the face images242.jpg
# Successfully downloaded: acne affecting the face images243.jpg
# Successfully downloaded: acne affecting the face images244.jpg
# Successfully downloaded: acne affecting the face images245.jpg
# Successfully downloaded: acne affecting the face images246.jpg
# Successfully downloaded: acne and other follicular disorder images421.jpg
# Successfully downloaded: acne and other follicular disorder images422.jpg
# Successfully downloaded: acne and other follicular disorder images423.jpg
# Successfully downloaded: acne and other follicular disorder images424.jpg
# Successfully downloaded: acne and other follicular disorder images425.jpg
# Successfully downloaded: acne and other follicular disorder images426.jpg
# Successfully downloaded: acne and other follicular disorder images427.jpg
# Successfully downloaded: acne and other follicular disorder images428.jpg
# Successfully downloaded: acne and other follicular disorder images429.jpg
# Successfully downloaded: acne and other follicular disorder images430.jpg
# Successfully downloaded: acne and other follicular disorder images431.jpg
# Successfully downloaded: acne and other follicular disorder images432.jpg
# Successfully downloaded: acne and other follicular disorder images433.jpg
# Successfully downloaded: acne and other follicular disorder images434.jpg
# Successfully downloaded: acne and other follicular disorder images435.jpg
# Successfully downloaded: acne and other follicular disorder images436.jpg
# Successfully downloaded: acne and other follicular disorder images437.jpg
# Successfully downloaded: acne and other follicular disorder images438.jpg
# Successfully downloaded: acne and other follicular disorder images439.jpg
# Successfully downloaded: acne and other follicular disorder images440.jpg
# Successfully downloaded: acne and other follicular disorder images441.jpg
# Successfully downloaded: acne and other follicular disorder images442.jpg
# Successfully downloaded: acne and other follicular disorder images443.jpg
# Successfully downloaded: acne and other follicular disorder images444.jpg
# Successfully downloaded: acne and other follicular disorder images445.jpg
# Successfully downloaded: acne and other follicular disorder images446.jpg
# Successfully downloaded: acne and other follicular disorder images447.jpg
# Successfully downloaded: acquired dermal macular hyperpigmentation images448.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images449.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images450.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images451.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images452.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images453.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images454.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images455.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images456.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images457.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images458.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images459.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images460.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images461.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images462.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images463.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images464.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images465.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images466.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images467.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images468.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images469.png
# Successfully downloaded: acquired dermal macular hyperpigmentation images470.jpg
# Successfully downloaded: acquired dermal macular hyperpigmentation images471.jpg
# Successfully downloaded: acquired dermal macular hyperpigmentation images472.jpg
# Successfully downloaded: acral lentiginous melanoma images473.jpg
# Successfully downloaded: acral lentiginous melanoma images474.jpg
# Successfully downloaded: acral lentiginous melanoma images475.jpg
# Successfully downloaded: acral lentiginous melanoma images476.png
# Successfully downloaded: acral lentiginous melanoma images477.jpg
# Successfully downloaded: acral lentiginous melanoma images478.jpg
# Successfully downloaded: acral lentiginous melanoma images479.jpg
# Successfully downloaded: acral lentiginous melanoma images480.jpg
# Successfully downloaded: acral lentiginous melanoma images481.jpg
# Successfully downloaded: acral lentiginous melanoma images482.png
# Successfully downloaded: acral lentiginous melanoma images483.jpg
# Successfully downloaded: acral lentiginous melanoma images484.jpg
# Successfully downloaded: acral lentiginous melanoma images485.jpg
# Successfully downloaded: acral lentiginous melanoma images486.jpg
# Successfully downloaded: acral lentiginous melanoma images487.jpg
# Successfully downloaded: acral lentiginous melanoma images488.jpg
# Successfully downloaded: acral lentiginous melanoma images489.jpg
# Successfully downloaded: acral lentiginous melanoma images490.jpg
# Successfully downloaded: acral lentiginous melanoma images491.jpg
# Successfully downloaded: acral lentiginous melanoma images492.jpg
# Successfully downloaded: acral lentiginous melanoma images493.jpg
# Successfully downloaded: acral lentiginous melanoma images494.jpg
# Successfully downloaded: acral lentiginous melanoma images495.jpg
# Successfully downloaded: acral lentiginous melanoma images496.jpg
# Successfully downloaded: acral lentiginous melanoma images497.jpg
# Successfully downloaded: acral lentiginous melanoma images498.jpg
# Successfully downloaded: acral lentiginous melanoma images499.jpg
# Successfully downloaded: acral lentiginous melanoma images500.jpg
# Successfully downloaded: acral lentiginous melanoma images501.jpg
# Successfully downloaded: acral lentiginous melanoma images502.jpg
# Successfully downloaded: acral lentiginous melanoma images503.jpg
# Successfully downloaded: actinic keratosis affecting the face images504.jpg
# Successfully downloaded: actinic keratosis affecting the face images505.jpg
# Successfully downloaded: actinic keratosis affecting the face images506.jpg
# Successfully downloaded: actinic keratosis affecting the face images507.jpg
# Successfully downloaded: actinic keratosis affecting the face images508.jpg
# Successfully downloaded: actinic keratosis affecting the face images509.jpg
# Successfully downloaded: actinic keratosis affecting the face images510.jpg
# Successfully downloaded: actinic keratosis affecting the face images511.jpg
# Successfully downloaded: actinic keratosis affecting the face images512.jpg
# Successfully downloaded: actinic keratosis affecting the face images513.jpg
# Successfully downloaded: actinic keratosis affecting the face images514.jpg
# Successfully downloaded: actinic keratosis affecting the face images515.jpg
# Successfully downloaded: actinic keratosis affecting the face images516.jpg
# Successfully downloaded: actinic keratosis affecting the face images517.jpg
# Successfully downloaded: actinic keratosis affecting the face images518.jpg
# Successfully downloaded: actinic keratosis affecting the face images519.jpg
# Successfully downloaded: actinic keratosis affecting the face images520.jpg
# Successfully downloaded: actinic keratosis affecting the face images521.jpg
# Successfully downloaded: actinic keratosis affecting the face images522.jpg
# Successfully downloaded: actinic keratosis affecting the face images523.jpg
# Successfully downloaded: actinic keratosis affecting the face images524.jpg
# Successfully downloaded: actinic keratosis affecting the face images525.jpg
# Successfully downloaded: actinic keratosis affecting the face images526.jpg
# Successfully downloaded: actinic keratosis affecting the face images527.jpg
# Successfully downloaded: actinic keratosis affecting the face images528.jpg
# Successfully downloaded: actinic keratosis affecting the face images529.jpg
# Successfully downloaded: actinic keratosis affecting the face images530.jpg
# Successfully downloaded: actinic keratosis affecting the face images531.jpg
# Successfully downloaded: actinic keratosis affecting the face images532.jpg
# Successfully downloaded: actinic keratosis affecting the face images533.jpg
# Successfully downloaded: actinic keratosis affecting the face images534.jpg
# Successfully downloaded: actinic keratosis affecting the face images535.jpg
# Successfully downloaded: actinic keratosis affecting the face images536.jpg
# Successfully downloaded: actinic keratosis affecting the face images537.jpg
# Successfully downloaded: actinic keratosis affecting the face images538.jpg
# Successfully downloaded: actinic keratosis affecting the face images539.jpg
# Successfully downloaded: actinic keratosis affecting the face images540.jpg
# Successfully downloaded: actinic keratosis affecting the face images541.jpg
# Successfully downloaded: actinic keratosis affecting the face images542.jpg
# Successfully downloaded: actinic keratosis affecting the face images543.jpg
# Successfully downloaded: actinic keratosis affecting the face images544.jpg
# Successfully downloaded: actinic keratosis affecting the face images545.jpg
# Successfully downloaded: actinic keratosis affecting the face images546.jpg
# Successfully downloaded: actinic keratosis affecting the face images547.jpg
# Successfully downloaded: actinic keratosis affecting the face images548.jpg
# Successfully downloaded: actinic keratosis affecting the face images549.jpg
# Successfully downloaded: actinic keratosis affecting the face images550.jpg
# Successfully downloaded: actinic keratosis affecting the face images551.jpg
# Successfully downloaded: actinic keratosis affecting the face images552.jpg
# Successfully downloaded: actinic keratosis affecting the face images553.jpg
# Successfully downloaded: actinic keratosis affecting the face images554.jpg
# Successfully downloaded: actinic keratosis affecting the face images555.jpg
# Successfully downloaded: actinic keratosis affecting the face images556.jpg
# Successfully downloaded: actinic keratosis affecting the face images557.jpg
# Successfully downloaded: actinic keratosis affecting the face images558.jpg
# Successfully downloaded: actinic keratosis affecting the face images559.jpg
# Successfully downloaded: actinic keratosis affecting the face images560.jpg
# Successfully downloaded: actinic keratosis affecting the face images561.jpg
# Successfully downloaded: actinic keratosis affecting the face images562.jpg
# Successfully downloaded: actinic keratosis affecting the face images563.jpg
# Successfully downloaded: actinic keratosis affecting the face images564.jpg
# Successfully downloaded: actinic keratosis affecting the face images565.jpg
# Successfully downloaded: actinic keratosis affecting the face images566.jpg
# Successfully downloaded: actinic keratosis affecting the face images567.jpg
# Successfully downloaded: actinic keratosis affecting the hand images568.jpg
# Successfully downloaded: actinic keratosis affecting the hand images569.jpg
# Successfully downloaded: actinic keratosis affecting the hand images570.jpg
# Successfully downloaded: actinic keratosis affecting the hand images571.jpg
# Successfully downloaded: actinic keratosis affecting the hand images572.jpg
# Successfully downloaded: actinic keratosis affecting the hand images573.jpg
# Successfully downloaded: actinic keratosis affecting the hand images574.jpg
# Successfully downloaded: actinic keratosis affecting the hand images575.jpg
# Successfully downloaded: actinic keratosis affecting the hand images576.jpg
# Successfully downloaded: actinic keratosis affecting the hand images577.jpg
# Successfully downloaded: actinic keratosis affecting the hand images578.jpg
# Successfully downloaded: actinic keratosis affecting the hand images579.jpg
# Successfully downloaded: actinic keratosis affecting the hand images580.jpg
# Successfully downloaded: actinic keratosis affecting the hand images581.jpg
# Successfully downloaded: actinic keratosis affecting the hand images582.jpg
# Successfully downloaded: actinic keratosis affecting the hand images583.jpg
# Successfully downloaded: actinic keratosis affecting the hand images584.jpg
# Successfully downloaded: actinic keratosis affecting the hand images585.jpg
# Successfully downloaded: actinic keratosis affecting the hand images586.jpg
# Successfully downloaded: actinic keratosis affecting the hand images587.jpg
# Successfully downloaded: actinic keratosis affecting the hand images588.jpg
# Successfully downloaded: actinic keratosis affecting the hand images589.jpg
# Successfully downloaded: actinic keratosis affecting the hand images590.jpg
# Successfully downloaded: actinic keratosis affecting the hand images591.jpg
# Successfully downloaded: actinic keratosis affecting the hand images592.jpg
# Successfully downloaded: actinic keratosis affecting the hand images593.jpg
# Successfully downloaded: actinic keratosis affecting the hand images594.jpg
# Successfully downloaded: actinic keratosis affecting the hand images595.jpg
# Successfully downloaded: actinic keratosis affecting the hand images596.jpg
# Successfully downloaded: actinic keratosis affecting the hand images597.jpg
# Successfully downloaded: actinic keratosis affecting the hand images598.jpg
# Successfully downloaded: actinic keratosis affecting the hand images599.jpg
# Successfully downloaded: actinic keratosis affecting the hand images600.jpg
# Successfully downloaded: actinic keratosis affecting the hand images601.jpg
# Successfully downloaded: actinic keratosis affecting the hand images602.jpg
# Successfully downloaded: actinic keratosis affecting the hand images603.jpg
# Successfully downloaded: actinic keratosis affecting the hand images604.jpg
# Successfully downloaded: actinic keratosis affecting the hand images605.jpg
# Successfully downloaded: actinic keratosis affecting the hand images606.jpg
# Successfully downloaded: actinic keratosis affecting the hand images607.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images608.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images609.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images610.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images611.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images612.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images613.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images614.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images615.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images616.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images617.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images618.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images619.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images620.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images621.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images622.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images623.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images624.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images625.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images626.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images627.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images628.jpg
# Successfully downloaded: actinic keratosis affecting the legs and feet images629.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images630.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images631.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images632.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images633.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images634.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images635.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images636.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images637.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images638.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images639.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images640.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images641.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images642.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images643.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images644.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images645.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images646.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images647.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images648.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images649.jpg
# Successfully downloaded: actinic keratosis affecting the scalp images650.jpg
# Successfully downloaded: actinic keratosis dermoscopy images651.jpg
# Successfully downloaded: actinic keratosis dermoscopy images652.jpg
# Successfully downloaded: actinic keratosis dermoscopy images653.jpg
# Successfully downloaded: actinic keratosis dermoscopy images654.jpg
# Successfully downloaded: actinic keratosis dermoscopy images655.jpg
# Successfully downloaded: actinic keratosis dermoscopy images656.jpg
# Successfully downloaded: actinic keratosis dermoscopy images657.jpg
# Successfully downloaded: actinic keratosis dermoscopy images658.jpg
# Successfully downloaded: actinic keratosis dermoscopy images659.jpg
# Successfully downloaded: actinic keratosis dermoscopy images660.jpg
# Successfully downloaded: actinic keratosis dermoscopy images661.jpg
# Successfully downloaded: actinic keratosis dermoscopy images662.jpg
# Successfully downloaded: actinic keratosis dermoscopy images663.jpg
# Successfully downloaded: actinic keratosis dermoscopy images664.jpg
# Successfully downloaded: actinic keratosis dermoscopy images665.jpg
# Successfully downloaded: actinic keratosis dermoscopy images666.jpg
# Successfully downloaded: actinic keratosis dermoscopy images667.jpg
# Successfully downloaded: actinic keratosis dermoscopy images668.jpg
# Successfully downloaded: actinic keratosis dermoscopy images669.jpg
# Successfully downloaded: actinic keratosis dermoscopy images670.jpg
# Successfully downloaded: actinic keratosis dermoscopy images671.jpg
# Successfully downloaded: actinic keratosis on the nose images672.jpg
# Successfully downloaded: actinic keratosis on the nose images673.jpg
# Successfully downloaded: actinic keratosis on the nose images674.jpg
# Successfully downloaded: actinic keratosis on the nose images675.jpg
# Successfully downloaded: actinic keratosis on the nose images676.jpg
